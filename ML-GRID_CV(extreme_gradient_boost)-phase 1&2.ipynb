# %%
import pandas as pd    #library used for processing table or excel,csv file....

# %%
dataset=pd.read_csv("insurance_pred.csv") #data collection
#dataset

# %%
dataset = pd.get_dummies(dataset,drop_first=True)   #data preprocessing...
#dataset

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[[ 'charges']]                                          #splitting input and output

# %%
from sklearn.model_selection import GridSearchCV  # it will automatically do train_test_split and model creation steps in traditional method.
from xgboost import XGBRegressor
param_grid={
    'learning_rate': [0.01,0.100],
    'n_estimators': [50, 100],
    'max_depth': [3,10],
    'min_child_weight': [1,10],
    'subsample': [0.1,1.0]}
                                                 #here we are using dictionary({}) to store hyper tunned parameter.
grid= GridSearchCV(XGBRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1], 'max_depth': [3, 10],
#                          'min_child_weight': [1, 10], 'n_estimators': [50, 100],
#                          'subsample': [0.1, 1.0]},
#              verbose=3)

# %%
results=grid.cv_results_
#print(result)
table= pd.DataFrame.from_dict(results)  #here we are using dictionary extension because we stored every hyper tunning parameter in dictionary above..
table                 #it will show the every combination of hyper tunned parameter and best model which gridcv find above , in a table here..


# it also used to compare this algorithm with different algorith using rank_test_score which is the best algorithm for this 
#given dataset and problem statement....
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.042304      0.002566         0.007117        0.000583
# 1        0.034691      0.004849         0.007723        0.001327
# 2        0.054936      0.004955         0.007442        0.001295
# 3        0.048431      0.003245         0.006557        0.000620
# 4        0.031478      0.001840         0.007459        0.001119
# 5        0.027827      0.002316         0.007613        0.000858
# 6        0.051617      0.006517         0.008065        0.001744
# 7        0.050333      0.004232         0.009073        0.001309
# 8        0.057081      0.005256         0.008012        0.000962
# 9        0.145564      0.004879         0.009324        0.001168
# 10       0.099646      0.005438         0.009736        0.000252
# 11       0.257022      0.013474         0.010234        0.000751
# 12       0.038700      0.003201         0.008932        0.001370
# 13       0.073928      0.007748         0.008926        0.001024
# 14       0.062504      0.002830         0.009629        0.000807
# 15       0.136250      0.006848         0.010025        0.000897
# 16       0.037900      0.004063         0.009127        0.001025
# 17       0.031994      0.003750         0.008017        0.001061
# 18       0.055640      0.003919         0.008728        0.000938
# 19       0.049677      0.001724         0.009026        0.001676
# 20       0.032783      0.002026         0.008324        0.000984
# 21       0.031177      0.001625         0.008231        0.000857
# 22       0.052703      0.001160         0.009056        0.001177
# 23       0.050174      0.002726         0.009700        0.001489
# 24       0.070474      0.004919         0.009503        0.001288
# 25       0.188810      0.014668         0.010784        0.000318
# 26       0.141612      0.008558         0.011234        0.001339
# 27       0.312111      0.018941         0.008434        0.001918
# 28       0.040947      0.000926         0.010541        0.001453
# 29       0.081463      0.003315         0.011172        0.001540
# 30       0.063800      0.002866         0.010719        0.001209
# 31       0.103913      0.008849         0.008937        0.002375
#
#     param_learning_rate  param_max_depth  param_min_child_weight  \
# 0                  0.01                3                       1
# 1                  0.01                3                       1
# 2                  0.01                3                       1
# 3                  0.01                3                       1
# 4                  0.01                3                      10
# 5                  0.01                3                      10
# 6                  0.01                3                      10
# 7                  0.01                3                      10
# 8                  0.01               10                       1
# 9                  0.01               10                       1
# 10                 0.01               10                       1
# 11                 0.01               10                       1
# 12                 0.01               10                      10
# 13                 0.01               10                      10
# 14                 0.01               10                      10
# 15                 0.01               10                      10
# 16                 0.10                3                       1
# 17                 0.10                3                       1
# 18                 0.10                3                       1
# 19                 0.10                3                       1
# 20                 0.10                3                      10
# 21                 0.10                3                      10
# 22                 0.10                3                      10
# 23                 0.10                3                      10
# 24                 0.10               10                       1
# 25                 0.10               10                       1
# 26                 0.10               10                       1
# 27                 0.10               10                       1
# 28                 0.10               10                      10
# 29                 0.10               10                      10
# 30                 0.10               10                      10
# 31                 0.10               10                      10
#
#     param_n_estimators  param_subsample  \
# 0                   50              0.1
# 1                   50              1.0
# 2                  100              0.1
# 3                  100              1.0
# 4                   50              0.1
# 5                   50              1.0
# 6                  100              0.1
# 7                  100              1.0
# 8                   50              0.1
# 9                   50              1.0
# 10                 100              0.1
# 11                 100              1.0
# 12                  50              0.1
# 13                  50              1.0
# 14                 100              0.1
# 15                 100              1.0
# 16                  50              0.1
# 17                  50              1.0
# 18                 100              0.1
# 19                 100              1.0
# 20                  50              0.1
# 21                  50              1.0
# 22                 100              0.1
# 23                 100              1.0
# 24                  50              0.1
# 25                  50              1.0
# 26                 100              0.1
# 27                 100              1.0
# 28                  50              0.1
# 29                  50              1.0
# 30                 100              0.1
# 31                 100              1.0
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...           0.536577
# 1   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...           0.551672
# 2   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...           0.741767
# 3   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...           0.760272
# 4   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...           0.521339
# 5   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...           0.551672
# 6   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...           0.716241
# 7   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...           0.760272
# 8   {'learning_rate': 0.01, 'max_depth': 10, 'min_...           0.533808
# 9   {'learning_rate': 0.01, 'max_depth': 10, 'min_...           0.538034
# 10  {'learning_rate': 0.01, 'max_depth': 10, 'min_...           0.737483
# 11  {'learning_rate': 0.01, 'max_depth': 10, 'min_...           0.736623
# 12  {'learning_rate': 0.01, 'max_depth': 10, 'min_...           0.521126
# 13  {'learning_rate': 0.01, 'max_depth': 10, 'min_...           0.551108
# 14  {'learning_rate': 0.01, 'max_depth': 10, 'min_...           0.715971
# 15  {'learning_rate': 0.01, 'max_depth': 10, 'min_...           0.756733
# 16  {'learning_rate': 0.1, 'max_depth': 3, 'min_ch...           0.876436
# 17  {'learning_rate': 0.1, 'max_depth': 3, 'min_ch...           0.882706
# 18  {'learning_rate': 0.1, 'max_depth': 3, 'min_ch...           0.874168
# 19  {'learning_rate': 0.1, 'max_depth': 3, 'min_ch...           0.877827
# 20  {'learning_rate': 0.1, 'max_depth': 3, 'min_ch...           0.872659
# 21  {'learning_rate': 0.1, 'max_depth': 3, 'min_ch...           0.881631
# 22  {'learning_rate': 0.1, 'max_depth': 3, 'min_ch...           0.878624
# 23  {'learning_rate': 0.1, 'max_depth': 3, 'min_ch...           0.876670
# 24  {'learning_rate': 0.1, 'max_depth': 10, 'min_c...           0.863355
# 25  {'learning_rate': 0.1, 'max_depth': 10, 'min_c...           0.829360
# 26  {'learning_rate': 0.1, 'max_depth': 10, 'min_c...           0.841459
# 27  {'learning_rate': 0.1, 'max_depth': 10, 'min_c...           0.816925
# 28  {'learning_rate': 0.1, 'max_depth': 10, 'min_c...           0.874194
# 29  {'learning_rate': 0.1, 'max_depth': 10, 'min_c...           0.858857
# 30  {'learning_rate': 0.1, 'max_depth': 10, 'min_c...           0.877515
# 31  {'learning_rate': 0.1, 'max_depth': 10, 'min_c...           0.853524
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.493818           0.512239           0.512772
# 1            0.518092           0.529814           0.540705
# 2            0.683636           0.722118           0.714013
# 3            0.708444           0.738133           0.736334
# 4            0.478410           0.494286           0.490938
# 5            0.518092           0.529814           0.540705
# 6            0.666224           0.699914           0.688308
# 7            0.708444           0.738133           0.736334
# 8            0.495677           0.512879           0.511357
# 9            0.514131           0.521570           0.539509
# 10           0.684524           0.722031           0.713390
# 11           0.696153           0.718243           0.728861
# 12           0.479908           0.494418           0.490434
# 13           0.520821           0.529750           0.541514
# 14           0.667619           0.700088           0.688198
# 15           0.708736           0.738816           0.733325
# 16           0.800213           0.882629           0.836311
# 17           0.813817           0.892385           0.853029
# 18           0.798316           0.875946           0.831168
# 19           0.810826           0.891714           0.848998
# 20           0.801243           0.878170           0.830002
# 21           0.813035           0.894476           0.850806
# 22           0.800843           0.880512           0.838716
# 23           0.810225           0.894974           0.848947
# 24           0.787944           0.874433           0.833566
# 25           0.767459           0.837757           0.816946
# 26           0.781612           0.855210           0.827728
# 27           0.758660           0.834006           0.810278
# 28           0.799445           0.875015           0.831882
# 29           0.789868           0.878191           0.828360
# 30           0.798005           0.877867           0.839720
# 31           0.780523           0.865626           0.825674
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.523361         0.515753        0.014099               29
# 1            0.539840         0.536025        0.011327               26
# 2            0.717160         0.715739        0.018728               21
# 3            0.744497         0.737536        0.016814               17
# 4            0.507418         0.498478        0.014695               32
# 5            0.539840         0.536025        0.011327               26
# 6            0.698551         0.693847        0.016457               24
# 7            0.744497         0.737536        0.016814               17
# 8            0.522815         0.515307        0.012692               30
# 9            0.528414         0.528332        0.009659               28
# 10           0.716243         0.714734        0.017248               22
# 11           0.719601         0.719896        0.013614               20
# 12           0.507310         0.498639        0.014261               31
# 13           0.537717         0.536182        0.010304               25
# 14           0.698299         0.694035        0.015924               23
# 15           0.741647         0.735851        0.015621               19
# 16           0.841296         0.847377        0.029903                7
# 17           0.869898         0.862367        0.027625                1
# 18           0.844053         0.844730        0.028912               10
# 19           0.862317         0.858337        0.027764                4
# 20           0.847600         0.845935        0.028310                8
# 21           0.869352         0.861860        0.028344                2
# 22           0.845437         0.848826        0.029353                5
# 23           0.863610         0.858885        0.028662                3
# 24           0.832117         0.838283        0.030099               12
# 25           0.822660         0.814836        0.024684               15
# 26           0.820042         0.825210        0.024891               14
# 27           0.820379         0.808050        0.025880               16
# 28           0.846350         0.845377        0.028290                9
# 29           0.855943         0.842244        0.030633               11
# 30           0.848631         0.848348        0.029431                6
# 31           0.846455         0.834361        0.029883               13

# %%
future_prediction= grid.predict([[19,27.900,0,False,True]])
print("future_prediction:{}".format(future_prediction))  # this is == to r2_score in traditional method.
# Out:
# future_prediction:[18299.281]

# %%
import pickle
filename="finalized_GRID_extreme_gradient_boost.sav"
pickle.dump(grid,open(filename,"wb")) # saving our best model by a new filename.

# %%
###PHASE-2

# %%
import pickle
loaded_model= pickle.load(open("finalized_GRID_extreme_gradient_boost.sav","rb"))#loading our model using saved file name
result= loaded_model.predict([[78,29.99,74,1,0]])
result                 #you can use this model by using this particular code for any future prediction in new file...
# Out:
# array([18567.79], dtype=float32)
